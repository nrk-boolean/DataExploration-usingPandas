# %%
import pandas as pd

#To install anually use !pip install pandas

# %%
info={
    "Name" : ["aa","bb","cc"],
    "CPA" : [88,651,1]
}
table_info=pd.DataFrame(info)

# %%
print(table_info)
# Out:
#   Name  CPA
# 0   aa   88
# 1   bb  651
# 2   cc    1

# %%
table_info
# Out:
#   Name  CPA
# 0   aa   88
# 1   bb  651
# 2   cc    1

# %%
# Working on "globalAirQuality" AQI DATA SET
df=pd.read_csv("globalAirQuality.csv")

df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df.tail()
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17995  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# ...

# %%
df.head(6)
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5  2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
# ...

# %%
df.sample()
# Out:
#                        timestamp country   city  latitude  longitude    pm25  \
# 5752  2025-11-19 10:25:17.554219      AE  Dubai    25.205     55.271  60.479
#
#         pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 5752  84.577  24.019  5.372  50.176  1.079  120        6.596     68.13
#
#       wind_speed
# 5752       3.888

# %%
df.sample(2)
# Out:
#                        timestamp country       city  latitude  longitude  \
# 4239  2025-11-16 09:25:17.554219      ZA  Cape Town   -33.925     18.424
# 1436  2025-11-19 14:25:17.554219      FR      Paris    48.857      2.352
#
#         pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 4239  63.794  56.353  18.323  6.439  18.258  0.668  127        5.085
# 1436  46.705  96.561  43.951  5.410  51.630  0.766  109       32.841
#
#       humidity  wind_speed
# 4239    40.141       6.713
# 1436    73.376       2.396

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#Data Selection

df["country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: str

# %%
df[["country","aqi"]]
# Out:
#       country  aqi
# 0          US  108
# 1          US   90
# 2          US   84
# 3          US  158
# 4          US   97
# ...       ...  ...
# 17995      CH  103
# 17996      CH  105
# 17997      CH  122
# 17998      CH   95
# 17999      CH   88
#
# [18000 rows x 2 columns]

# %%
df.loc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.loc[0:2]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650

# %%
df.iloc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df.iloc[0,9] #Value accessing Just Like array
# Out:
# np.float64(52.568)

# %%
df.iloc[0:2]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18000, step=1)

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='str')

# %%
df.loc[0,"aqi"]
# Out:
# np.int64(108)

# %%
df.loc[0:2,["aqi","city"]]
# Out:
#    aqi      city
# 0  108  New York
# 1   90  New York
# 2   84  New York

# %%
df.iloc[0:3,[11,2]]
# Out:
#    aqi      city
# 0  108  New York
# 1   90  New York
# 2   84  New York

# %%
df.iloc[0:3,-13:-6:1]
# Out:
#        city  latitude  longitude    pm25     pm10     no2    so2
# 0  New York    40.713    -74.006  50.295  108.938  27.998  6.539
# 1  New York    40.713    -74.006  32.083   63.043  36.120  4.021
# 2  New York    40.713    -74.006  42.250   82.553  26.935  9.538

# %%
df.iloc[0:3,-4:-14:-1]
# Out:
#    aqi     co      o3    so2     no2     pm10    pm25  longitude  latitude  \
# 0  108  1.096  52.568  6.539  27.998  108.938  50.295    -74.006    40.713
# 1   90  1.075  43.536  4.021  36.120   63.043  32.083    -74.006    40.713
# 2   84  0.977  23.320  9.538  26.935   82.553  42.250    -74.006    40.713
#
#        city
# 0  New York
# 1  New York
# 2  New York

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.loc[0,"city"]
# Out:
# 'New York'

# %%
df.iloc[0,1]
# Out:
# 'US'

# %%
df.iloc[0,9]
# Out:
# np.float64(52.568)

# %%
df.iat[0,2]
# Out:
# 'New York'

# %%
df.at[0,'city']
# Out:
# 'New York'

# %%
cities=df["city"].copy() #Need to delete the modified Data
cities[0]="MumBai" #View of a slice of df, and Modifing

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
cities
# Out:
# 0          MumBai
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: str

# %%
#Filtering of data

#AQI greater then 100
df[df["aqi"]>100]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["aqi"]>100) & (df["temperature"]>30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["aqi"]>100) & (df["temperature"]<30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# 12     2025-11-05 06:25:17.554219      US  New York    40.713    -74.006
# 13     2025-11-05 07:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17988  2025-11-19 06:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[ (df["aqi"]>100) & (df["temperature"]<30) ][ [ "city","country" ] ] #Filtering using [row][column]
# Out:
#            city country
# 0      New York      US
# 3      New York      US
# 8      New York      US
# 12     New York      US
# 13     New York      US
# ...         ...     ...
# 17988    Zurich      CH
# 17993    Zurich      CH
# 17995    Zurich      CH
# 17996    Zurich      CH
# 17997    Zurich      CH
#
# [7337 rows x 2 columns]

# %%
df.loc[(df["aqi"]>100) & (df["temperature"]<30),["city","country"]] #Filtering with loc & iloc
# Out:
#            city country
# 0      New York      US
# 3      New York      US
# 8      New York      US
# 12     New York      US
# 13     New York      US
# ...         ...     ...
# 17988    Zurich      CH
# 17993    Zurich      CH
# 17995    Zurich      CH
# 17996    Zurich      CH
# 17997    Zurich      CH
#
# [7337 rows x 2 columns]

# %%
df[0:2]["aqi"] #No table format for single column
# Out:
# 0    108
# 1     90
# Name: aqi, dtype: int64

# %%
df[0:2][["aqi","city"]] #Same as above but gives table format, if multiple columns given
# Out:
#    aqi      city
# 0  108  New York
# 1   90  New York

# %%
df[(df["aqi"]>100) & (df["temperature"]<30)]["aqi"] #No table format for single column
# Out:
# 0        108
# 3        158
# 8        121
# 12       114
# 13       124
#         ...
# 17988    122
# 17993    153
# 17995    103
# 17996    105
# 17997    122
# Name: aqi, Length: 7337, dtype: int64

# %%
df[(df["aqi"]>100) & (df["temperature"]<30)][["aqi","city"]] #Same as above but gives table format, if multiple columns given
# Out:
#        aqi      city
# 0      108  New York
# 3      158  New York
# 8      121  New York
# 12     114  New York
# 13     124  New York
# ...    ...       ...
# 17988  122    Zurich
# 17993  153    Zurich
# 17995  103    Zurich
# 17996  105    Zurich
# 17997  122    Zurich
#
# [7337 rows x 2 columns]
